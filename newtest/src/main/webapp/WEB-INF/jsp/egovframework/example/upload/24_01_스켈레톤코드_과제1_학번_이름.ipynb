# %% [markdown]
# # **본 노트북 파일은 '파이썬이해와활용' 과제1에 대한 skeleton code 입니다.**

# %% [markdown]
# 문제1. 함수 getStatistics()는 가변인자 *를 사용하여 여러 숫자를 입력받은 후 입력받은 숫자들에 대해서 개수, 평균, 분산, 표준편차를 구하는 함수를 작성하시오. 단, 평균, 분산, 표준편차는 5주차 수업 모듈 및 함수 활용에서 언급하였던 numpy 패키지를 사용하여 구하시오. [2점]
#
# ---
#
# 함수 호출에 따른 결과 예시)
#
#
# ---
#
#
#
# 함수 호출 예1)
#
# cnt, mean, var, std = getStatistics(1,2,3,4,5)
#
# print("숫자 개수:", cnt)
#
# print("평균:", mean)
#
# print("분산:", var)
#
# print("표준편차:", std, "\n")
#
#
#
# 결과 예1)
#
# 숫자 개수: 5
#
# 평균: 3.0
#
# 분산: 2.0
#
# 표준편차: 1.4142135623730951
#
#
# ---
#
#
# 함수 호출 예2)
#
# cnt, mean, var, std = getStatistics(90, 100, 95)
#
# print("숫자 개수:", cnt)
#
# print("평균:", mean)
#
# print("분산:", var)
#
# print("표준편차:", std, "\n")
#
#
# 결과 예2)
#
# 숫자 개수: 3
#
# 평균: 95.0
#
# 분산: 16.666666666666668
#
# 표준편차: 4.08248290463863
#
#
# ---
#
#
# 함수 호출 예3)
#
# cnt, mean, var, std = getStatistics(10)
#
# print("숫자 개수:", cnt)
#
# print("평균:", mean)
#
# print("분산:", var)
#
# print("표준편차:", std, "\n")
#
#
# 결과 예3)
#
# 숫자 개수: 1
#
# 평균: 10.0
#
# 분산: 0.0
#
# 표준편차: 0.0

# %%
import numpy as np

def getStatistics(*values):
    cnt = 0 # count of elements
    mean = 0 # mean
    var = 0 # variance
    std = 0 # standard deviation

    ### Modify code here ###


    ### End of your code ###

    return cnt, mean, var, std

cnt, mean, var, std = getStatistics(1,2,3,4,5)
print("숫자 개수:", cnt)
print("평균:", mean)
print("분산:", var)
print("표준편차:", std, "\n")

cnt, mean, var, std = getStatistics(90, 100, 95)
print("숫자 개수:", cnt)
print("평균:", mean)
print("분산:", var)
print("표준편차:", std, "\n")

cnt, mean, var, std = getStatistics(10)
print("숫자 개수:", cnt)
print("평균:", mean)
print("분산:", var)
print("표준편차:", std, "\n")

# %% [markdown]
# 문제 2. 입력받은 숫자 n이하의 5의 배수의 개수를 출력한 이후, 해당 개수 만큼 *를 출력할 수 있는 함수 printStar()의 코드를 작성하시오. [4점]
#
# ---
#
# 함수 호출 예1)
#
# printStar(1)
#
# <br/>
#
# 출력 결과 예1)
#
# 입력받은 숫자 1 이하 5의 배수는 0 개 존재함
#
# ---
#
# 함수 호출 예2)
#
# printStar(12)
#
# <br/>
#
# 출력 결과 예2)
#
#
# 입력받은 숫자 12 이하 5의 배수는 2 개 존재함
# <br/>
# *
#
# *
#
# ---
#
# 함수 호출 예3)
#
# printStar(23)
#
# <br/>
#
# 입력받은 숫자 23 이하 5의 배수는 4 개 존재함
# <br/>
# *
#
# *
#
# *
#
# *
#
# ---
#
# 함수 호출 예4)
#
# printStar(50)
#
# <br/>
#
# 입력받은 숫자 50 이하 5의 배수는 10 개 존재함
# <br/>
# *
#
# *
#
# *
#
# *
#
# *
#
# *
#
# *
#
# *
#
# *
#
# *

# %%
def printStar(n):
    #### Modify code here ####


    #### End of the code ####

printStar(1)
printStar(12)
printStar(23)
printStar(50)

# %% [markdown]
# 문제3. 0부터 20까지 임의의 정수 한 개를 입력으로 받아, 입력받은 해당 정수 이하 홀수에 대해서만 합계를 구하고 출력할 수 있는 함수를 구현하시오. (단, for문을 사용하여 구현하시오) [4점]
#
# ---
#
# 함수 호출 예1)
# sumOddNumber(1)
# <br/>
# 출력 결과 예1)
#
# 현재 입력받은 정수: 1
#
# sum: 1
#
# ---
#
# 함수 호출 예2)
# sumOddNumber(8)
# <br/>
# 출력 결과 예2)
#
# 현재 입력받은 정수: 8
#
# sum: 16
#
# ---
#
# 함수 호출 예3)
# sumOddNumber(13)
# <br/>
#
# 출력 결과 예3)
#
# 현재 입력받은 정수: 13
#
# sum: 49

# %%
def sumOddNumber(max_num):
    sum = 0
    print("현재 입력받은 정수:", max_num)

    ### Modify code here ###


    ### End of your code ###

    print("sum:", sum)
    print("")

sumOddNumber(1)
sumOddNumber(8)
sumOddNumber(13)
